# %% [markdown]
# Python基础

# %%
int(1/3)
# Out:
# 0

# %%
12/(4+1)
# Out:
# 2.4

# %%
1.0/3
# Out:
# 0.3333333333333333

# %%
import nltk

# %%
nltk.download()
# Out:
# showing info http://www.nltk.org/nltk_data/
# True

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %% [markdown]
# 搜索文本

# %%
text1.concordance("monstrous")
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
text5.concordance("im")
# Out:
# Displaying 25 of 149 matches:
# now im left with this gay name :P PART hey e
# what did you but on e-bay i feel like im in the wrong room yeee haw U30 im con
# ike im in the wrong room yeee haw U30 im considering changing my nickname to "
#  the hell outta my freaking PM box .. Im with my fiance !!!!!!!!!!!!!!!! answe
# m impressed . PART hiya room lmao !!! im doin alright thanks omg Finger .. Dee
# th lol JOIN so read it . thanks U7 .. Im happy to have my fiance here !! forwa
# i didnt me phone you . . . sheesh now im that phone perv guy lets hope not U12
# to spain ? i need to go this summer . im a HUGE phone perv ok seriously who wa
# an ... . ACTION video tapes . hey U20 Im blind now . ACTION has left the room
# T u got that right , i dont do shit , im the supervisor Hello U165 . hey U165
#  him in the " untouchable " list U115 im good U6 lmao U7 how r u U128 hehe how
# can I ask where ya all are from ..... im here in kentucky as I said ... too wi
# ...

# %%
text1.similar("monstrous")#出现在相似上下文中的词
# Out:
# true contemptible christian abundant few part mean careful puzzled
# mystifying passing curious loving wise doleful gamesome singular
# delightfully perilous fearless

# %%
text2.common_contexts(["monstrous","very"])#两个或两个以上词汇的上下文
# Out:
# am_glad a_pretty a_lucky is_pretty be_glad

# %%
text1.similar("true")
# Out:
# all in of that this on he not seen as there other see now known it
# take hand be for

# %%
text1.common_contexts(["monstrous","wise"])
# Out:
# most_and

# %%
text4.dispersion_plot(["citizens","democracy","freedom","duties","America"])#离散图，每一列一个单词，每一行代表整个文本

# %%
text3.generate()#以文章风格生成随即文本
# Out:
# Building ngram index...
# laid by her , and said unto Cain , Where art thou , and said , Go to ,
# I will not do it for ten ' s sons ; we dreamed each man according to
# their generatio the firstborn said unto Laban , Because I said , Nay ,
# but Sarah shall her name be . , duke Elah , duke Shobal , and Akan .
# and looked upon my affliction . Bashemath Ishmael ' s blood , but Isra
# for as a prince hast thou found of all the cattle in the valley , and
# the wo The
# "laid by her , and said unto Cain , Where art thou , and said , Go to ,\nI will not do it for ten ' s sons ; we dreamed each man according to\ntheir generatio the firstborn said unto Laban , Because I said , Nay ,\nbut Sarah shall her name be . , duke Elah , duke Shobal , and Akan .\nand looked upon my affliction . Bashemath Ishmael ' s blood , but Isra\nfor as a prince hast thou found of all the cattle in the valley , and\nthe wo The"

# %%
len(text3)#统计单词和标点符号 “标识符”
# Out:
# 44764

# %%
sorted(set(text3))#词汇条目的排序表
# Out:
# ['!',
#  "'",
#  '(',
#  ')',
#  ',',
#  ',)',
#  '.',
#  '.)',
#  ':',
#  ';',
#  ';)',
#  '?',
#  '?)',
#  'A',
#  'Abel',
#  'Abelmizraim',
#  'Abidah',
#  'Abide',
#  'Abimael',
#  'Abimelech',
#  'Abr',
#  'Abrah',
#  'Abraham',
#  'Abram',
#  'Accad',
#  'Achbor',
#  'Adah',
#  'Adam',
#  'Adbeel',
#  'Admah',
#  'Adullamite',
#  'After',
#  'Aholibamah',
#  'Ahuzzath',
#  'Ajah',
#  'Akan',
#  'All',
#  'Allonbachuth',
#  'Almighty',
#  'Almodad',
#  'Also',
#  'Alvah',
#  'Alvan',
#  'Am',
#  'Amal',
#  'Amalek',
#  'Amalekites',
#  'Ammon',
#  'Amorite',
#  'Amorites',
#  'Amraphel',
#  'An',
#  'Anah',
#  'Anamim',
#  'And',
#  'Aner',
#  'Angel',
#  'Appoint',
#  'Aram',
#  'Aran',
#  'Ararat',
#  'Arbah',
#  'Ard',
#  'Are',
#  'Areli',
#  'Arioch',
#  'Arise',
#  'Arkite',
#  'Arodi',
#  'Arphaxad',
#  'Art',
#  'Arvadite',
#  'As',
#  'Asenath',
#  'Ashbel',
#  'Asher',
#  'Ashkenaz',
#  'Ashteroth',
#  'Ask',
#  'Asshur',
#  'Asshurim',
#  'Assyr',
#  'Assyria',
# ...

# %%
len(set(text3)) #2789个词汇或者说词类型，词类型指的是一个词在一个文本中独一无二的出现或拼写方式，也就是说其为唯一的
# Out:
# 2789

# %%
from __future__ import division #确保浮点数除法

# %%
len(text3)/len(set(text3))#词汇丰富度，每个词平均被使用了十六次
# Out:
# 16.050197203298673

# %%
text3.count("smote")#一个单词在文本中出现的次数
# Out:
# 5

# %%
100*text4.count("a")/len(text4)#算出 a 占整个文本的百分之几
# Out:
# 1.4643016433938312

# %%
text5.count("lol")
# Out:
# 704

# %%
100*text5.count("lol")/len(text5)
# Out:
# 1.5640968673628082

# %%
def lexical_diversity(text):
    return len(text)/len(set(text))#text参数是计算文本词汇多样性的占位符

# %%
def percentage(count,total):
    return 100*count/total

# %%
lexical_diversity(text3)
# Out:
# 16.050197203298673

# %%
lexical_diversity(text5)
# Out:
# 7.420046158918563

# %%
percentage(4,5)#放在数据值位置的是实参
# Out:
# 80.0

# %%
percentage(text4.count('a'),len(text4))
# Out:
# 1.4643016433938312

# %%
sent1=['Call','me','Ishmael','.']
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.']

# %%
len(sent1)
# Out:
# 4

# %%
lexical_diversity(sent1)
# Out:
# 1.0

# %%
sent2=['The','Family','of','Dsahwood','had','long','been','settled','in','Sussex','.']
sent3=['In','the','beginning','God','created','the','heaven','and','the','earth','.']

# %%
sent1+sent2#链表连接
# Out:
# ['Call',
#  'me',
#  'Ishmael',
#  '.',
#  'The',
#  'Family',
#  'of',
#  'Dsahwood',
#  'had',
#  'long',
#  'been',
#  'settled',
#  'in',
#  'Sussex',
#  '.']

# %%
sent1.append("Some")#追加
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.', 'Some', 'Some']

# %%
text4[173]#索引
# Out:
# 'awaken'

# %%
text4.index('awaken')#一个词第一次出现时的索引
# Out:
# 173

# %%
text5[16715:16735]#切片
# Out:
# ['U86',
#  'thats',
#  'why',
#  'something',
#  'like',
#  'gamefly',
#  'is',
#  'so',
#  'good',
#  'because',
#  'you',
#  'can',
#  'actually',
#  'play',
#  'a',
#  'full',
#  'game',
#  'without',
#  'buying',
#  'it']

# %%
sent=['word1','word2','word3','word4','word5','word6','word7','word8','word9','word10']
sent[0]
# Out:
# 'word1'

# %%
sent[5:8] #索引5，6，7 m:n表示元素m到n-1
# Out:
# ['word6', 'word7', 'word8']

# %%
sent[:3]
# Out:
# ['word1', 'word2', 'word3']

# %%
text2[14212:]
# Out:
# ['the',
#  'valleys',
#  'beneath',
#  'shut',
#  'up',
#  'their',
#  'superior',
#  'beauties',
#  ';',
#  'and',
#  'towards',
#  'one',
#  'of',
#  'these',
#  'hills',
#  'did',
#  'Marianne',
#  'and',
#  'Margaret',
#  'one',
#  'memorable',
#  'morning',
#  'direct',
#  'their',
#  'steps',
#  ',',
#  'attracted',
#  'by',
#  'the',
#  'partial',
#  'sunshine',
#  'of',
#  'a',
#  'showery',
#  'sky',
#  ',',
#  'and',
#  'unable',
#  'longer',
#  'to',
#  'bear',
#  'the',
#  'confinement',
#  'which',
#  'the',
#  'settled',
#  'rain',
#  'of',
#  'the',
#  'two',
#  'preceding',
#  'days',
#  'had',
#  'occasioned',
#  '.',
#  'The',
#  'weather',
#  'was',
#  'not',
#  'tempting',
#  'enough',
#  'to',
#  'draw',
#  'the',
#  'two',
#  'others',
#  'from',
#  'their',
#  'pencil',
#  'and',
#  'their',
#  'book',
#  ',',
#  'in',
#  'spite',
#  'of',
#  'Marianne',
#  "'",
#  's',
#  'declaration',
#  'that',
#  'the',
#  'day',
#  'would',
#  'be',
#  'lastingly',
# ...

# %%
sent[0]='First'
sent[9]='Last'
sent
# Out:
# ['First',
#  'word2',
#  'word3',
#  'word4',
#  'word5',
#  'word6',
#  'word7',
#  'word8',
#  'word9',
#  'Last']

# %%
sent[1:9]=['Second','Third']
sent
# Out:
# ['First', 'Second', 'Third', 'Last']

# %%
my_sent=['Bravely','bold','Sir','Robin',',','rode']#字母开头，可以包含数字和下划线

# %%
noun_phrase=my_sent[1:4]
noun_phrase
# Out:
# ['bold', 'Sir', 'Robin']

# %%
wOrDs=sorted(noun_phrase)#sorted() 对字符串是按字符的 Unicode/ASCII 码值排序，大写字母因为码点更小，会排在小写字母前面
wOrDs
# Out:
# ['Robin', 'Sir', 'bold']

# %%
vocab=set(text1)
vocab_size=len(vocab)
vocab_size#名称区分大小写 myVar和Myvar不一样
# Out:
# 19317

# %%
name='Monty'
print(name[0],name[4])#字符串
print(name*2,name+'1')
# Out:
# M y
# MontyMonty Monty1

# %%
''.join(['Monty','Python'])#连接
# Out:
# 'MontyPython'

# %%
'Monty Python'.split()
# Out:
# ['Monty', 'Python']

# %%
saying=['After','all','is','said','and','done','more','is','said','than','done']
print(set(saying))
print(sorted(set(saying)))
tokens=sorted(set(saying))
tokens[-2:]#从倒数第 2 个开始，取到最后一个（包含最后一个）
# Out:
# {'all', 'more', 'is', 'and', 'than', 'done', 'said', 'After'}
# ['After', 'all', 'and', 'done', 'is', 'more', 'said', 'than']
# ['said', 'than']

# %%
fdist1=FreqDist(text1)#频率分布 传递文本的名称作为参数
fdist1
# Out:
# FreqDist({',': 18713, 'the': 13721, '.': 6862, 'of': 6536, 'and': 6024, 'a': 4569, 'to': 4542, ';': 4072, 'in': 3916, 'that': 2982, ...})

# %%
vocab=list(fdist1.keys())#需要
print(vocab[:50])
# Out:
# ['[', 'Moby', 'Dick', 'by', 'Herman', 'Melville', '1851', ']', 'ETYMOLOGY', '.', '(', 'Supplied', 'a', 'Late', 'Consumptive', 'Usher', 'to', 'Grammar', 'School', ')', 'The', 'pale', '--', 'threadbare', 'in', 'coat', ',', 'heart', 'body', 'and', 'brain', ';', 'I', 'see', 'him', 'now', 'He', 'was', 'ever', 'dusting', 'his', 'old', 'lexicons', 'grammars', 'with', 'queer', 'handkerchief', 'mockingly', 'embellished', 'all']

# %%
fdist1['whale']
# Out:
# 906

# %%
fdist1.plot(50,cumulative=True)#频率前50词 累加
# Out:
# <Axes: xlabel='Samples', ylabel='Cumulative Counts'>

# %%
fdist1.hapaxes()#找出 text1 里只出现过 1 次的所有单词！
# Out:
# ['Herman',
#  'Melville',
#  ']',
#  'ETYMOLOGY',
#  'Late',
#  'Consumptive',
#  'School',
#  'threadbare',
#  'lexicons',
#  'mockingly',
#  'flags',
#  'mortality',
#  'signification',
#  'HACKLUYT',
#  'Sw',
#  'HVAL',
#  'roundness',
#  'Dut',
#  'Ger',
#  'WALLEN',
#  'WALW',
#  'IAN',
#  'RICHARDSON',
#  'KETOS',
#  'GREEK',
#  'CETUS',
#  'LATIN',
#  'WHOEL',
#  'ANGLO',
#  'SAXON',
#  'WAL',
#  'HWAL',
#  'SWEDISH',
#  'ICELANDIC',
#  'BALEINE',
#  'BALLENA',
#  'FEGEE',
#  'ERROMANGOAN',
#  'Librarian',
#  'painstaking',
#  'burrower',
#  'grub',
#  'Vaticans',
#  'stalls',
#  'higgledy',
#  'piggledy',
#  'gospel',
#  'promiscuously',
#  'commentator',
#  'belongest',
#  'sallow',
#  'Pale',
#  'Sherry',
#  'loves',
#  'bluntly',
#  'Subs',
#  'thankless',
#  'Hampton',
#  'Court',
#  'hie',
#  'refugees',
#  'pampered',
#  'Michael',
#  'Raphael',
#  'unsplinterable',
#  'GENESIS',
#  'JOB',
#  'JONAH',
#  'punish',
#  'ISAIAH',
#  'soever',
#  'cometh',
# ...

# %%
V=set(text1)
long_words=[w for w in V if len(w)>15]
sorted(long_words)#产生一个链表而非集合，可能有相同元素
# Out:
# ['CIRCUMNAVIGATION',
#  'Physiognomically',
#  'apprehensiveness',
#  'cannibalistically',
#  'characteristically',
#  'circumnavigating',
#  'circumnavigation',
#  'circumnavigations',
#  'comprehensiveness',
#  'hermaphroditical',
#  'indiscriminately',
#  'indispensableness',
#  'irresistibleness',
#  'physiognomically',
#  'preternaturalness',
#  'responsibilities',
#  'simultaneousness',
#  'subterraneousness',
#  'supernaturalness',
#  'superstitiousness',
#  'uncomfortableness',
#  'uncompromisedness',
#  'undiscriminating',
#  'uninterpenetratingly']

# %%
fdist5=FreqDist(text5)
sorted([w for w in set(text5) if len(w)>7 and fdist5[w]>7])#长度大于五次数大于七次
# Out:
# ['#14-19teens',
#  '#talkcity_adults',
#  '((((((((((',
#  '........',
#  'Question',
#  'actually',
#  'anything',
#  'computer',
#  'cute.-ass',
#  'everyone',
#  'football',
#  'innocent',
#  'listening',
#  'remember',
#  'seriously',
#  'something',
#  'together',
#  'tomorrow',
#  'watching']

# %%
#双连词
bigrams(['more','is','said','than','done'])#句子里的词两两一组配对
# Out:
# <generator object bigrams at 0x0000015641BE6CE0>

# %%
text4.collocations()
# Out:
# United States; fellow citizens; four years; years ago; Federal
# Government; General Government; American people; Vice President; Old
# World; Almighty God; Fellow citizens; Chief Magistrate; Chief Justice;
# God bless; every citizen; Indian tribes; public debt; one another;
# foreign nations; political parties

# %%
[len(w) for w in text1]#把 text1 里每个单词的长度算出来，做成一个【数字列表】
# Out:
# [1,
#  4,
#  4,
#  2,
#  6,
#  8,
#  4,
#  1,
#  9,
#  1,
#  1,
#  8,
#  2,
#  1,
#  4,
#  11,
#  5,
#  2,
#  1,
#  7,
#  6,
#  1,
#  3,
#  4,
#  5,
#  2,
#  10,
#  2,
#  4,
#  1,
#  5,
#  1,
#  4,
#  1,
#  3,
#  5,
#  1,
#  1,
#  3,
#  3,
#  3,
#  1,
#  2,
#  3,
#  4,
#  7,
#  3,
#  3,
#  8,
#  3,
#  8,
#  1,
#  4,
#  1,
#  5,
#  12,
#  1,
#  9,
#  11,
#  4,
#  3,
#  3,
#  3,
#  5,
#  2,
#  3,
#  3,
#  5,
#  7,
#  2,
#  3,
#  5,
#  1,
#  2,
#  5,
#  2,
#  4,
#  3,
#  3,
#  8,
#  1,
#  2,
#  7,
#  6,
#  8,
#  3,
#  2,
#  3,
#  9,
#  1,
#  1,
#  5,
#  3,
#  4,
#  2,
#  4,
#  2,
#  6,
#  6,
#  1,
#  3,
#  2,
#  5,
#  4,
#  2,
#  4,
#  4,
#  1,
#  5,
#  1,
#  4,
#  2,
#  2,
#  2,
#  6,
#  2,
#  3,
#  6,
#  7,
#  3,
#  1,
#  7,
#  9,
#  1,
#  3,
#  6,
#  1,
#  1,
#  5,
#  6,
#  5,
#  6,
#  3,
#  13,
#  2,
#  3,
#  4,
#  1,
#  3,
#  7,
#  4,
#  5,
#  2,
#  3,
#  4,
#  2,
#  2,
#  8,
#  1,
#  5,
#  1,
#  3,
#  2,
#  1,
#  3,
#  3,
#  1,
#  4,
#  1,
#  4,
#  6,
#  2,
#  5,
#  4,
#  9,
# ...

# %%
fdist=FreqDist([len(w) for w in text1])
fdist.keys()#以频率递减顺序排序的样本链表
# Out:
# dict_keys([1, 4, 2, 6, 8, 9, 11, 5, 7, 3, 10, 12, 13, 14, 16, 15, 17, 18, 20])

# %%
fdist.items()#把词频表变成「单词 + 次数」一对一对的全部数据
# Out:
# dict_items([(1, 47933), (4, 42345), (2, 38513), (6, 17111), (8, 9966), (9, 6428), (11, 1873), (5, 26597), (7, 14399), (3, 50223), (10, 3528), (12, 1053), (13, 567), (14, 177), (16, 22), (15, 70), (17, 12), (18, 1), (20, 1)])

# %%
fdist.max()#数值最大的样本
# Out:
# 3

# %%
fdist[3]
# Out:
# 50223

# %%
fdist.freq(3)#频率 占比
# Out:
# 0.19255882431878046

# %%
sent7
# Out:
# ['Pierre',
#  'Vinken',
#  ',',
#  '61',
#  'years',
#  'old',
#  ',',
#  'will',
#  'join',
#  'the',
#  'board',
#  'as',
#  'a',
#  'nonexecutive',
#  'director',
#  'Nov.',
#  '29',
#  '.']

# %%
[w for w in sent7 if len(w) < 4]
# Out:
# [',', '61', 'old', ',', 'the', 'as', 'a', '29', '.']

# %%
[w for w in sent7 if len(w) != 4]
# Out:
# ['Pierre',
#  'Vinken',
#  ',',
#  '61',
#  'years',
#  'old',
#  ',',
#  'the',
#  'board',
#  'as',
#  'a',
#  'nonexecutive',
#  'director',
#  '29',
#  '.']

# %% [markdown]
# # 字符串判断方法（词汇专用）
# w.startswith("xxx")  # 以...开头
# w.endswith("xxx")    # 以...结尾
# w.isupper()          # 全大写
# w.islower()          # 全小写
# w.istitle()          # 首字母大写
# w.isalpha()          # 纯字母
# w.isdigit()          # 纯数字

# %%
sorted([w for w in set(text1) if w.endswith('ableness')])
# Out:
# ['comfortableness',
#  'honourableness',
#  'immutableness',
#  'indispensableness',
#  'indomitableness',
#  'intolerableness',
#  'palpableness',
#  'reasonableness',
#  'uncomfortableness']

# %%
sorted([term for term in set(text4) if 'gnt' in term])#找出 text4 中 包含子串 gnt 的所有单词，去重，排序后输出。
# Out:
# ['Sovereignty', 'sovereignties', 'sovereignty']

# %%
sorted([item for item in set(text6) if item.istitle()])#找出 text6 中 首字母大写 的所有单词，去重，排序后输出。
# Out:
# ['A',
#  'Aaaaaaaaah',
#  'Aaaaaaaah',
#  'Aaaaaah',
#  'Aaaah',
#  'Aaaaugh',
#  'Aaagh',
#  'Aaah',
#  'Aaauggh',
#  'Aaaugh',
#  'Aaauugh',
#  'Aagh',
#  'Aah',
#  'Aauuggghhh',
#  'Aauuugh',
#  'Aauuuuugh',
#  'Aauuuves',
#  'Action',
#  'Actually',
#  'African',
#  'Ages',
#  'Aggh',
#  'Agh',
#  'Ah',
#  'Ahh',
#  'Alice',
#  'All',
#  'Allo',
#  'Almighty',
#  'Alright',
#  'Am',
#  'Amen',
#  'An',
#  'Anarcho',
#  'And',
#  'Angnor',
#  'Anthrax',
#  'Antioch',
#  'Anybody',
#  'Anyway',
#  'Apples',
#  'Aramaic',
#  'Are',
#  'Arimathea',
#  'Armaments',
#  'Arthur',
#  'As',
#  'Ask',
#  'Assyria',
#  'At',
#  'Attila',
#  'Augh',
#  'Autumn',
#  'Auuuuuuuugh',
#  'Away',
#  'Ay',
#  'Ayy',
#  'B',
#  'Back',
#  'Bad',
#  'Badon',
#  'Battle',
#  'Be',
#  'Beast',
#  'Bedevere',
#  'Bedwere',
#  'Behold',
#  'Between',
#  'Beyond',
#  'Black',
#  'Bloody',
#  'Blue',
#  'Bon',
#  'Bones',
#  'Book',
#  'Bors',
#  'Brave',
#  'Bravely',
#  'Bravest',
#  'Bread',
# ...

# %%
sorted([item for item in set(sent7) if item.isdigit()])
# Out:
# ['29', '61']

# %%
sorted([w for w in set(text7) if '-' in w and 'index' in w])#找出 text7 中包含连字符 - 且包含 index 的单词，去重，排序输出
# Out:
# ['Stock-index',
#  'index-arbitrage',
#  'index-fund',
#  'index-options',
#  'index-related',
#  'stock-index']

# %%
sorted([wd for wd in set(text3) if wd.istitle() and len(wd)>10])
# Out:
# ['Abelmizraim',
#  'Allonbachuth',
#  'Beerlahairoi',
#  'Canaanitish',
#  'Chedorlaomer',
#  'Girgashites',
#  'Hazarmaveth',
#  'Hazezontamar',
#  'Ishmeelites',
#  'Jegarsahadutha',
#  'Jehovahjireh',
#  'Kirjatharba',
#  'Melchizedek',
#  'Mesopotamia',
#  'Peradventure',
#  'Philistines',
#  'Zaphnathpaaneah']

# %%
sorted([w for w in set(sent7) if not w.islower()])#找出 sent7 中不是全小写的单词，去重，排序输出。
# Out:
# [',', '.', '29', '61', 'Nov.', 'Pierre', 'Vinken']

# %%
sorted([t for t in set(text2) if 'cie' in t or 'cei' in t])
# Out:
# ['ancient',
#  'ceiling',
#  'conceit',
#  'conceited',
#  'conceive',
#  'conscience',
#  'conscientious',
#  'conscientiously',
#  'deceitful',
#  'deceive',
#  'deceived',
#  'deceiving',
#  'deficiencies',
#  'deficiency',
#  'deficient',
#  'delicacies',
#  'excellencies',
#  'fancied',
#  'insufficiency',
#  'insufficient',
#  'legacies',
#  'perceive',
#  'perceived',
#  'perceiving',
#  'prescience',
#  'prophecies',
#  'receipt',
#  'receive',
#  'received',
#  'receiving',
#  'society',
#  'species',
#  'sufficient',
#  'sufficiently',
#  'undeceive',
#  'undeceiving']

# %%
[w.upper() for w in text1]
# Out:
# ['[',
#  'MOBY',
#  'DICK',
#  'BY',
#  'HERMAN',
#  'MELVILLE',
#  '1851',
#  ']',
#  'ETYMOLOGY',
#  '.',
#  '(',
#  'SUPPLIED',
#  'BY',
#  'A',
#  'LATE',
#  'CONSUMPTIVE',
#  'USHER',
#  'TO',
#  'A',
#  'GRAMMAR',
#  'SCHOOL',
#  ')',
#  'THE',
#  'PALE',
#  'USHER',
#  '--',
#  'THREADBARE',
#  'IN',
#  'COAT',
#  ',',
#  'HEART',
#  ',',
#  'BODY',
#  ',',
#  'AND',
#  'BRAIN',
#  ';',
#  'I',
#  'SEE',
#  'HIM',
#  'NOW',
#  '.',
#  'HE',
#  'WAS',
#  'EVER',
#  'DUSTING',
#  'HIS',
#  'OLD',
#  'LEXICONS',
#  'AND',
#  'GRAMMARS',
#  ',',
#  'WITH',
#  'A',
#  'QUEER',
#  'HANDKERCHIEF',
#  ',',
#  'MOCKINGLY',
#  'EMBELLISHED',
#  'WITH',
#  'ALL',
#  'THE',
#  'GAY',
#  'FLAGS',
#  'OF',
#  'ALL',
#  'THE',
#  'KNOWN',
#  'NATIONS',
#  'OF',
#  'THE',
#  'WORLD',
#  '.',
#  'HE',
#  'LOVED',
#  'TO',
#  'DUST',
#  'HIS',
#  'OLD',
#  'GRAMMARS',
#  ';',
#  'IT',
#  'SOMEHOW',
#  'MILDLY',
#  'REMINDED',
#  'HIM',
#  'OF',
#  'HIS',
#  'MORTALITY',
#  '.',
#  '"',
# ...

# %%
print(
    len(text1),                  # 总词数
    len(set(text1)),              # 不同词数（大小写算不同）
    len(set(word.lower() for word in text1)),  # 不同词数（不区分大小写）
    len(set(word.lower() for word in text1 if word.isalpha()))  # 纯字母、不区分大小写的不同词数
)
# Out:
# 260819 19317 17231 16948

# %%
sent1=['Call','me','Ishmael','.']
for xyzzy in sent1:
    if xyzzy.endswith('l'):
        print(xyzzy)
# Out:
# Call
# Ishmael

# %%
tricky = sorted([w for w in set(text2) if 'cie' in w or 'cei' in w])
for word in tricky:
    print(word)
# Out:
# ancient
# ceiling
# conceit
# conceited
# conceive
# conscience
# conscientious
# conscientiously
# deceitful
# deceive
# deceived
# deceiving
# deficiencies
# deficiency
# deficient
# delicacies
# excellencies
# fancied
# insufficiency
# insufficient
# legacies
# perceive
# perceived
# perceiving
# prescience
# prophecies
# receipt
# receive
# received
# receiving
# society
# species
# sufficient
# sufficiently
# undeceive
# undeceiving

# %% [markdown]
# 语言理解技术
# 1.词义消歧 dish serve;by
# 2.指代消解 确定代词和名词短语指的是什么   语义角色标注  确定名词短语如何与动词相关联
# 3.自动生成语言
# 4.机器翻译（MT）
# 5.人机对话系统
# 6.文本含义

# %%
nltk.chat.chatbots()
# Out:
# Which chatbot would you like to talk to?
#   1: Eliza (psycho-babble)
#   2: Iesha (teen anime junky)
#   3: Rude (abusive bot)
#   4: Suntsu (Chinese sayings)
#   5: Zen (gems of wisdom)
# Enter a number in the range 1-5:  1
# Therapist
# ---------
# Talk to the program by typing in plain English, using normal upper-
# and lower-case letters and punctuation.  Enter "quit" when done.
# ...
# Hello.  How are you feeling today?
# > good
# I see.
# > haha
# I see.
# > what
# How do you feel when you say that?
# > The pig that John found looked happy
# I see.  And what does that tell you?
# > german
# I see.  And what does that tell you?
